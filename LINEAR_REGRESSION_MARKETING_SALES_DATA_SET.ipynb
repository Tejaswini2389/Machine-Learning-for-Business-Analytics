# %%
import pandas as pd
import numpy as np

# %%
MS=pd.read_csv("//content/marketing_sales_dataset.csv")

# %%
MS.head()
# Out:
#    marketing_spend         sales  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0             8270  21747.672060         NaN         NaN         NaN
# 1             1860   2820.618137         NaN         NaN         NaN
# 2             6390  17216.096430         NaN         NaN         NaN
# 3             6191  15155.625250         NaN         NaN         NaN
# 4             6734  16058.471200         NaN         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# 2         NaN         NaN         NaN         NaN         NaN  ...
# 3         NaN         NaN         NaN         NaN         NaN  ...
# 4         NaN         NaN         NaN         NaN         NaN  ...
#
#    Unnamed: 1244  Unnamed: 1245  Unnamed: 1246  Unnamed: 1247  Unnamed: 1248  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    Unnamed: 1249  Unnamed: 1250  Unnamed: 1251  Unnamed: 1252  Unnamed: 1253
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
# [5 rows x 1254 columns]

# %%
MS.tail()
# Out:
#      marketing_spend         sales  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 195             7546  21580.761580         NaN         NaN         NaN
# 196             2986   6598.393186         NaN         NaN         NaN
# 197             9338  23752.645460         NaN         NaN         NaN
# 198             3911  10895.718410         NaN         NaN         NaN
# 199             2734   8580.083183         NaN         NaN         NaN
#
#      Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 195         NaN         NaN         NaN         NaN         NaN  ...
# 196         NaN         NaN         NaN         NaN         NaN  ...
# 197         NaN         NaN         NaN         NaN         NaN  ...
# 198         NaN         NaN         NaN         NaN         NaN  ...
# 199         NaN         NaN         NaN         NaN         NaN  ...
#
#      Unnamed: 1244  Unnamed: 1245  Unnamed: 1246  Unnamed: 1247  \
# 195            NaN            NaN            NaN            NaN
# 196            NaN            NaN            NaN            NaN
# 197            NaN            NaN            NaN            NaN
# 198            NaN            NaN            NaN            NaN
# 199            NaN            NaN            NaN            NaN
#
#      Unnamed: 1248  Unnamed: 1249  Unnamed: 1250  Unnamed: 1251  \
# 195            NaN            NaN            NaN            NaN
# 196            NaN            NaN            NaN            NaN
# 197            NaN            NaN            NaN            NaN
# 198            NaN            NaN            NaN            NaN
# 199            NaN            NaN            NaN            NaN
#
#      Unnamed: 1252  Unnamed: 1253
# 195            NaN            NaN
# 196            NaN            NaN
# 197            NaN            NaN
# 198            NaN            NaN
# 199            NaN            NaN
#
# [5 rows x 1254 columns]

# %%
MS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Columns: 1254 entries, marketing_spend to Unnamed: 1253
# dtypes: float64(1252), int64(1), object(1)
# memory usage: 1.9+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(x="marketing_spend",y="sales",data=MS)
# Out:
# <Axes: xlabel='marketing_spend', ylabel='sales'>

# %%
# import ML model
from sklearn.linear_model import LinearRegression

# %%
X=MS[["marketing_spend"]]
Y=MS["sales"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([20873.25712659, 15465.07459184,  7587.72184251, 11791.30919161,
#        14427.92313531, 22480.21709417,  5036.07934344, 15959.90829881,
#        16674.66809776, 20583.35455079, 19993.55275865, 22845.09447406,
#         4976.09950017,  3001.76299257, 20648.33271433,  3346.64709137,
#        20018.54436001, 11099.04183388,  7907.61433995, 24157.15354557,
#        18771.46345204, 18886.42481831,  4498.75991416, 23814.76860691,
#        22565.1885388 ,  5328.48107938, 15982.40074003, 22625.16838207,
#        20066.0284026 , 17624.34894952, 23639.82739737, 14225.49116428,
#        22807.60707202, 20855.76300564, 22820.1028727 , 21298.11434975,
#        16462.23948619, 16817.12022553, 14680.33830907, 16027.38562249])

# %%
# model evaluation
from sklearn.metrics import r2_score
print("R2_Score",r2_score(Y_test,y_pred))
# Out:
# R2_Score 0.9038233995267846

# %%
plt.scatter(X,Y)
plt.plot(X,model.predict(X),color="black")

# %%
model.coef_
# Out:
# array([2.49916014])

# %%
model.intercept_
# Out:
# np.float64(342.65660764467975)

# %%
y=(2.4787828*6000)+342.65660764467975
y
# Out:
# 15215.35340764468
