# %%
import pandas as pd

# %%
RS=pd.read_csv("/content/retail_store_sales_dataset.csv")

# %%
RS.head()
# Out:
#    transaction_id       city         store product_category product_name  \
# 0            5001       Pune  Central Mall       Home Decor   Face Cream
# 1            5002  Bangalore   City Center       Home Decor    Wall Lamp
# 2            5003  Hyderabad  Central Mall         Clothing        Jeans
# 3            5004  Hyderabad  Smart Bazaar       Home Decor        Mixer
# 4            5005  Hyderabad  Central Mall           Beauty   Headphones
#
#    unit_price  quantity customer_type payment_method  discount_percent  \
# 0        2386         4     Returning           Card                15
# 1        1383         1           New           Card                10
# 2        4937         1     Returning            UPI                 5
# 3        1470         2     Returning            UPI                10
# 4        2688         1           New           Cash                10
#
#    total_sale  discount_amount  final_amount
# 0        9544          1431.60       8112.40
# ...

# %%
RS.tail()
# Out:
#      transaction_id       city         store product_category product_name  \
# 215            5216  Hyderabad  Smart Bazaar       Home Decor        Jeans
# 216            5217     Mysore  Urban Retail           Beauty     Rice Bag
# 217            5218       Pune  Smart Bazaar      Electronics        Jeans
# 218            5219    Chennai  Urban Retail        Groceries      T-shirt
# 219            5220    Chennai  Central Mall       Home Decor   Headphones
#
#      unit_price  quantity customer_type payment_method  discount_percent  \
# 215        1809         3           New           Card                15
# 216        4696         1     Returning           Cash                15
# 217        3699         4           New           Cash                 0
# 218        2845         4           New            UPI                15
# 219        2783         1     Returning           Card                10
#
#      total_sale  discount_amount  final_amount
# ...

# %%
RS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    220 non-null    int64
#  1   city              220 non-null    object
#  2   store             220 non-null    object
#  3   product_category  220 non-null    object
#  4   product_name      220 non-null    object
#  5   unit_price        220 non-null    int64
#  6   quantity          220 non-null    int64
#  7   customer_type     220 non-null    object
#  8   payment_method    220 non-null    object
#  9   discount_percent  220 non-null    int64
#  10  total_sale        220 non-null    int64
#  11  discount_amount   220 non-null    float64
#  12  final_amount      220 non-null    float64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 22.5+ KB

# %%
RS.shape
#How many transactions are recorded in the dataset
# Out:
# (220, 13)

# %%
RS["city"].unique()
#What are the different cities present in the dataset
# Out:
# array(['Pune', 'Bangalore', 'Hyderabad', 'Mysore', 'Chennai'],
#       dtype=object)

# %%
RS["product_category"].unique()
#How many product categories exist
# Out:
# array(['Home Decor', 'Clothing', 'Beauty', 'Electronics', 'Groceries'],
#       dtype=object)

# %%
len(RS["product_category"].unique())
#How many product categories exist
# Out:
# 5

# %%
RS.head(10)
#Display the first 10 rows
# Out:
#    transaction_id       city         store product_category product_name  \
# 0            5001       Pune  Central Mall       Home Decor   Face Cream
# 1            5002  Bangalore   City Center       Home Decor    Wall Lamp
# 2            5003  Hyderabad  Central Mall         Clothing        Jeans
# 3            5004  Hyderabad  Smart Bazaar       Home Decor        Mixer
# 4            5005  Hyderabad  Central Mall           Beauty   Headphones
# 5            5006     Mysore  Urban Retail      Electronics     Rice Bag
# 6            5007  Hyderabad    Metro Mart       Home Decor    Wall Lamp
# 7            5008    Chennai  Central Mall      Electronics        Mixer
# 8            5009       Pune  Central Mall      Electronics    Wall Lamp
# 9            5010  Bangalore   City Center       Home Decor    Wall Lamp
#
#    unit_price  quantity customer_type payment_method  discount_percent  \
# 0        2386         4     Returning           Card                15
# ...

# %%
RS.groupby("product_category")["quantity"].sum().idxmax()
#Which product category is sold the most
# Out:
# 'Groceries'

# %%
RS.groupby("store")["total_sale"].sum().idxmax()
#Which store has the highest number of transaction
# Out:
# 'Smart Bazaar'

# %%
RS["city"].value_counts().idxmax()
#Which city has the most customers
# Out:
# 'Hyderabad'

# %%
RS["final_amount"].mean()
#What is the average purchase value
# Out:
# np.float64(5581.942045454545)

# %%
RS["total_sale"].max()
#What is the maximum purchase value
# Out:
# 19900

# %%
RS.groupby("city")["final_amount"].sum().idxmax()
#Which city generates the highest revenue
# Out:
# 'Hyderabad'

# %%
RS["payment_method"].value_counts().idxmax()
# Which payment method is used the most
# Out:
# 'Card'

# %%
RS.groupby("customer_type")["final_amount"].sum().idxmax()
#Are new customers or returning customers purchasing more
# Out:
# 'New'

# %%
RS.groupby("product_category")["final_amount"].sum().idxmax()
# Which product category generates the highest revenue
# Out:
# 'Groceries'

# %%
RS.groupby("store")["discount_amount"].sum().idxmax()
#Which store gives the highest total discoun
# Out:
# 'Smart Bazaar'

# %%
RS.groupby("product_name")["quantity"].sum().idxmax()
#Which product sells the most units
# Out:
# 'Mixer'

# %%
RS.groupby("city")["final_amount"].mean().idxmax()
#Which city has the highest average purchase value
# Out:
# 'Mysore'

# %%
cu_Returning=RS[RS["customer_type"]=="Returning"]
cu_Returning['customer_type']
#Which product category is most popular among returning customers
# Out:
# 0      Returning
# 2      Returning
# 3      Returning
# 5      Returning
# 8      Returning
#          ...
# 211    Returning
# 212    Returning
# 213    Returning
# 216    Returning
# 219    Returning
# Name: customer_type, Length: 114, dtype: object

# %%
cu_Returning.groupby("product_category")["customer_type"].sum().idxmax()
#Which product category is most popular among returning customers
# Out:
# 'Groceries'

# %%
cu_Returning["product_category"].value_counts().idxmax()
#Which product category is most popular among returning customers
# Out:
# 'Groceries'
