# %%
import pandas as pd

# %%
MS=pd.read_csv("/content/marketing_sales_dataset (1).csv")

# %%
MS.head()
# Out:
#    marketing_spend         sales
# 0             8270  21747.672065
# 1             1860   2820.618137
# 2             6390  17216.096432
# 3             6191  15155.625246
# 4             6734  16058.471202

# %%
MS.tail()
# Out:
#      marketing_spend         sales
# 195             7546  21580.761576
# 196             2986   6598.393186
# 197             9338  23752.645455
# 198             3911  10895.718405
# 199             2734   8580.083183

# %%
MS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   marketing_spend  200 non-null    int64
#  1   sales            200 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 3.3 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(x="marketing_spend",y="sales",data=MS)
# Out:
# <Axes: xlabel='marketing_spend', ylabel='sales'>

# %%
# import ML model
from sklearn.model_selection import train_test_split

# %%
X=MS[["marketing_spend"]]
Y=MS[["sales"]]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
# import ml model
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X_test)
Y_pred
# Out:
# array([[20873.25712655],
#        [15465.07459195],
#        [ 7587.72184283],
#        [11791.30919182],
#        [14427.92313545],
#        [22480.21709409],
#        [ 5036.07934383],
#        [15959.9082989 ],
#        [16674.66809784],
#        [20583.35455076],
#        [19993.55275863],
#        [22845.09447397],
#        [ 4976.09950057],
#        [ 3001.76299301],
#        [20648.3327143 ],
#        [ 3346.6470918 ],
#        [20018.54435999],
#        [11099.04183411],
#        [ 7907.61434026],
#        [24157.15354544],
#        [18771.46345206],
#        [18886.42481832],
#        [ 4498.75991456],
#        [23814.76860679],
#        [22565.18853872],
#        [ 5328.48107976],
#        [15982.40074013],
#        [22625.16838199],
#        [20066.02840258],
#        [17624.34894957],
#        [23639.82739726],
#        [14225.49116442],
#        [22807.60707193],
#        [20855.7630056 ],
#        [22820.10287261],
#        [21298.1143497 ],
#        [16462.23948627],
#        [16817.1202256 ],
#        [14680.3383092 ],
#        [16027.38562258]])
